# %%
import pandas as pd
from TS import Series

# %%
path_50mV_0muMCa_0Que = './data/50mV_0muMCa_0Que/'
path_50mV_0muMCa_10Que = './data/50mV_0muMCa_10Que/'
path_50mV_0muMCa_100Que = './data/50mV_0muMCa_100Que/'
path_50mV_10muMCa_0Que = './data/50mV_10muMCa_0Que/'
path_50mV_10muMCa_10Que = './data/50mV_10muMCa_10Que/'
path_50mV_10muMCa_100Que = './data/50mV_10muMCa_100Que/'
path_50mV_100muMCa_0Que = './data/50mV_100muMCa_0Que/'
path_50mV_100muMCa_10Que = './data/50mV_100muMCa_10Que/'
path_50mV_100muMCa_100Que = './data/50mV_100muMCa_100Que/'

# %% [markdown]
# ### 0% Ca vs Quercetin

# %%
ts_50mV_0muMCa_0Que_hbe43 = Series(path_50mV_0muMCa_0Que + 'hbe43.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe45 = Series(path_50mV_0muMCa_0Que + 'hbe45.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe46 = Series(path_50mV_0muMCa_0Que + 'hbe45.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe47 = Series(path_50mV_0muMCa_0Que + 'hbe46.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe49 = Series(path_50mV_0muMCa_0Que + 'hbe49.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe114 = Series(path_50mV_0muMCa_0Que + 'hbe114.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe118 = Series(path_50mV_0muMCa_0Que + 'hbe118.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe120 = Series(path_50mV_0muMCa_0Que + 'hbe120.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe125 = Series(path_50mV_0muMCa_0Que + 'hbe125.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe134 = Series(path_50mV_0muMCa_0Que + 'hbe134.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe135 = Series(path_50mV_0muMCa_0Que + 'hbe135.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe137 = Series(path_50mV_0muMCa_0Que + 'hbe137.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe138 = Series(path_50mV_0muMCa_0Que + 'hbe138.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe141 = Series(path_50mV_0muMCa_0Que + 'hbe141.txt', '0Ca/0Que')

ts_50mV_0muMCa_10Que_hbe50 = Series(path_50mV_0muMCa_10Que + 'hbe50.txt', '0Ca/10Que')
ts_50mV_0muMCa_10Que_hbe51 = Series(path_50mV_0muMCa_10Que + 'hbe51.txt', '0Ca/10Que')
ts_50mV_0muMCa_10Que_hbe52 = Series(path_50mV_0muMCa_10Que + 'hbe52.txt', '0Ca/10Que')
ts_50mV_0muMCa_10Que_hbe54 = Series(path_50mV_0muMCa_10Que + 'hbe54.txt', '0Ca/10Que')
ts_50mV_0muMCa_10Que_hbe56 = Series(path_50mV_0muMCa_10Que + 'hbe56.txt', '0Ca/10Que')

ts_50mV_0muMCa_100Que_hbe115 = Series(path_50mV_0muMCa_100Que + 'hbe115.txt', '0Ca/100Que')
ts_50mV_0muMCa_100Que_hbe117 = Series(path_50mV_0muMCa_100Que + 'hbe117.txt', '0Ca/100Que')
ts_50mV_0muMCa_100Que_hbe123 = Series(path_50mV_0muMCa_100Que + 'hbe123.txt', '0Ca/100Que')

# %%
df_ts_50mV_0muMCa_0Que_hbe43 = ts_50mV_0muMCa_0Que_hbe43.make_df()
df_ts_50mV_0muMCa_0Que_hbe45 = ts_50mV_0muMCa_0Que_hbe45.make_df()
df_ts_50mV_0muMCa_0Que_hbe46 = ts_50mV_0muMCa_0Que_hbe46.make_df()
df_ts_50mV_0muMCa_0Que_hbe47 = ts_50mV_0muMCa_0Que_hbe47.make_df()
df_ts_50mV_0muMCa_0Que_hbe49 = ts_50mV_0muMCa_0Que_hbe49.make_df()
df_ts_50mV_0muMCa_0Que_hbe114 = ts_50mV_0muMCa_0Que_hbe114.make_df()
df_ts_50mV_0muMCa_0Que_hbe118 = ts_50mV_0muMCa_0Que_hbe118.make_df()
df_ts_50mV_0muMCa_0Que_hbe120 = ts_50mV_0muMCa_0Que_hbe120.make_df()
df_ts_50mV_0muMCa_0Que_hbe125 = ts_50mV_0muMCa_0Que_hbe125.make_df()
df_ts_50mV_0muMCa_0Que_hbe134 = ts_50mV_0muMCa_0Que_hbe134.make_df()
df_ts_50mV_0muMCa_0Que_hbe135 = ts_50mV_0muMCa_0Que_hbe135.make_df()
df_ts_50mV_0muMCa_0Que_hbe137 = ts_50mV_0muMCa_0Que_hbe137.make_df()
df_ts_50mV_0muMCa_0Que_hbe138 = ts_50mV_0muMCa_0Que_hbe138.make_df()
df_ts_50mV_0muMCa_0Que_hbe141 = ts_50mV_0muMCa_0Que_hbe141.make_df()

df_ts_50mV_0muMCa_10Que_hbe50 = ts_50mV_0muMCa_10Que_hbe50.make_df()
df_ts_50mV_0muMCa_10Que_hbe51 = ts_50mV_0muMCa_10Que_hbe51.make_df()
df_ts_50mV_0muMCa_10Que_hbe52 = ts_50mV_0muMCa_10Que_hbe52.make_df()
df_ts_50mV_0muMCa_10Que_hbe54 = ts_50mV_0muMCa_10Que_hbe54.make_df()
df_ts_50mV_0muMCa_10Que_hbe56 = ts_50mV_0muMCa_10Que_hbe56.make_df()

df_ts_50mV_0muMCa_100Que_hbe115 = ts_50mV_0muMCa_100Que_hbe115.make_df()
df_ts_50mV_0muMCa_100Que_hbe117 = ts_50mV_0muMCa_100Que_hbe117.make_df()
df_ts_50mV_0muMCa_100Que_hbe123 = ts_50mV_0muMCa_100Que_hbe123.make_df()

# %%
df_0ca = pd.concat([
    df_ts_50mV_0muMCa_0Que_hbe43,
    df_ts_50mV_0muMCa_0Que_hbe45,
    df_ts_50mV_0muMCa_0Que_hbe46,
    df_ts_50mV_0muMCa_0Que_hbe47,
    df_ts_50mV_0muMCa_0Que_hbe49,
    df_ts_50mV_0muMCa_0Que_hbe114,
    df_ts_50mV_0muMCa_0Que_hbe118,
    df_ts_50mV_0muMCa_0Que_hbe120,
    df_ts_50mV_0muMCa_0Que_hbe125,
    df_ts_50mV_0muMCa_0Que_hbe134,
    df_ts_50mV_0muMCa_0Que_hbe135,
    df_ts_50mV_0muMCa_0Que_hbe137,
    df_ts_50mV_0muMCa_0Que_hbe138,
    df_ts_50mV_0muMCa_0Que_hbe141,
    df_ts_50mV_0muMCa_10Que_hbe50,
    df_ts_50mV_0muMCa_10Que_hbe51,
    df_ts_50mV_0muMCa_10Que_hbe52,
    df_ts_50mV_0muMCa_10Que_hbe54,
    df_ts_50mV_0muMCa_10Que_hbe56,
    df_ts_50mV_0muMCa_100Que_hbe115,
    df_ts_50mV_0muMCa_100Que_hbe117,
    df_ts_50mV_0muMCa_100Que_hbe123,
    ])

# %%
df_0ca.dropna(inplace=True)

# %%
df_0ca.to_csv('./prepared_datasets/0_Ca_classification.csv',
                 index=False)

# %% [markdown]
# ## 10% Ca vs Quercetin

# %%
ts_50mV_10muMCa_0Que_hbe59 = Series(path_50mV_10muMCa_0Que + 'hbe59.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe62 = Series(path_50mV_10muMCa_0Que + 'hbe62.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe150 = Series(path_50mV_10muMCa_0Que + 'hbe150.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe236 = Series(path_50mV_10muMCa_0Que + 'hbe236.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe238 = Series(path_50mV_10muMCa_0Que + 'hbe238.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe240 = Series(path_50mV_10muMCa_0Que + 'hbe240.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe249 = Series(path_50mV_10muMCa_0Que + 'hbe249.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe251 = Series(path_50mV_10muMCa_0Que + 'hbe251.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe253 = Series(path_50mV_10muMCa_0Que + 'hbe253.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe263 = Series(path_50mV_10muMCa_0Que + 'hbe263.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe265 = Series(path_50mV_10muMCa_0Que + 'hbe265.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe322 = Series(path_50mV_10muMCa_0Que + 'hbe322.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe370 = Series(path_50mV_10muMCa_0Que + 'hbe370.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe378 = Series(path_50mV_10muMCa_0Que + 'hbe378.txt', '10Ca/0Que')

ts_50mV_10muMCa_10Que_hbe58 = Series(path_50mV_10muMCa_10Que + 'hbe58.txt', '10Ca/10Que')
ts_50mV_10muMCa_10Que_hbe374 = Series(path_50mV_10muMCa_10Que + 'hbe374.txt', '10Ca/10Que')
ts_50mV_10muMCa_10Que_hbe379 = Series(path_50mV_10muMCa_10Que + 'hbe379.txt', '10Ca/10Que')
ts_50mV_10muMCa_10Que_hbe381 = Series(path_50mV_10muMCa_10Que + 'hbe381.txt', '10Ca/10Que')
ts_50mV_10muMCa_10Que_hbe397 = Series(path_50mV_10muMCa_10Que + 'hbe397.txt', '10Ca/10Que')

ts_50mV_10muMCa_100Que_hbe241 = Series(path_50mV_10muMCa_100Que + 'hbe241.txt', '10Ca/100Que')
ts_50mV_10muMCa_100Que_hbe242 = Series(path_50mV_10muMCa_100Que + 'hbe242.txt', '10Ca/100Que')
ts_50mV_10muMCa_100Que_hbe256 = Series(path_50mV_10muMCa_100Que + 'hbe256.txt', '10Ca/100Que')
ts_50mV_10muMCa_100Que_hbe258 = Series(path_50mV_10muMCa_100Que + 'hbe258.txt', '10Ca/100Que')
ts_50mV_10muMCa_100Que_hbe260 = Series(path_50mV_10muMCa_100Que + 'hbe260.txt', '10Ca/100Que')
ts_50mV_10muMCa_100Que_hbe268 = Series(path_50mV_10muMCa_100Que + 'hbe268.txt', '10Ca/100Que')

# %%
df_ts_50mV_10muMCa_0Que_hbe59 = ts_50mV_10muMCa_0Que_hbe59.make_df()
df_ts_50mV_10muMCa_0Que_hbe62 = ts_50mV_10muMCa_0Que_hbe62.make_df()
df_ts_50mV_10muMCa_0Que_hbe150 = ts_50mV_10muMCa_0Que_hbe150.make_df()
df_ts_50mV_10muMCa_0Que_hbe236 = ts_50mV_10muMCa_0Que_hbe236.make_df()
df_ts_50mV_10muMCa_0Que_hbe238 = ts_50mV_10muMCa_0Que_hbe238.make_df()
df_ts_50mV_10muMCa_0Que_hbe240 = ts_50mV_10muMCa_0Que_hbe240.make_df()
df_ts_50mV_10muMCa_0Que_hbe249 = ts_50mV_10muMCa_0Que_hbe249.make_df()
df_ts_50mV_10muMCa_0Que_hbe251 = ts_50mV_10muMCa_0Que_hbe251.make_df()
df_ts_50mV_10muMCa_0Que_hbe253 = ts_50mV_10muMCa_0Que_hbe253.make_df()
df_ts_50mV_10muMCa_0Que_hbe263 = ts_50mV_10muMCa_0Que_hbe263.make_df()
df_ts_50mV_10muMCa_0Que_hbe265 = ts_50mV_10muMCa_0Que_hbe265.make_df()
df_ts_50mV_10muMCa_0Que_hbe322 = ts_50mV_10muMCa_0Que_hbe322.make_df()
df_ts_50mV_10muMCa_0Que_hbe370 = ts_50mV_10muMCa_0Que_hbe370.make_df()
df_ts_50mV_10muMCa_0Que_hbe378 = ts_50mV_10muMCa_0Que_hbe378.make_df()

df_ts_50mV_10muMCa_10Que_hbe58 = ts_50mV_10muMCa_10Que_hbe58.make_df()
df_ts_50mV_10muMCa_10Que_hbe374 = ts_50mV_10muMCa_10Que_hbe374.make_df()
df_ts_50mV_10muMCa_10Que_hbe379 = ts_50mV_10muMCa_10Que_hbe379.make_df()
df_ts_50mV_10muMCa_10Que_hbe381 = ts_50mV_10muMCa_10Que_hbe381.make_df()
df_ts_50mV_10muMCa_10Que_hbe397 = ts_50mV_10muMCa_10Que_hbe397.make_df()

df_ts_50mV_10muMCa_100Que_hbe241 = ts_50mV_10muMCa_100Que_hbe241.make_df()
df_ts_50mV_10muMCa_100Que_hbe242 = ts_50mV_10muMCa_100Que_hbe242.make_df()
df_ts_50mV_10muMCa_100Que_hbe256 = ts_50mV_10muMCa_100Que_hbe256.make_df()
df_ts_50mV_10muMCa_100Que_hbe258 = ts_50mV_10muMCa_100Que_hbe258.make_df()
df_ts_50mV_10muMCa_100Que_hbe260 = ts_50mV_10muMCa_100Que_hbe260.make_df()
df_ts_50mV_10muMCa_100Que_hbe268 = ts_50mV_10muMCa_100Que_hbe268.make_df()

# %%
df_10ca = pd.concat([
    df_ts_50mV_10muMCa_0Que_hbe59,
    df_ts_50mV_10muMCa_0Que_hbe62,
    df_ts_50mV_10muMCa_0Que_hbe150,
    df_ts_50mV_10muMCa_0Que_hbe236,
    df_ts_50mV_10muMCa_0Que_hbe238,
    df_ts_50mV_10muMCa_0Que_hbe240,
    df_ts_50mV_10muMCa_0Que_hbe249,
    df_ts_50mV_10muMCa_0Que_hbe251,
    df_ts_50mV_10muMCa_0Que_hbe253,
    df_ts_50mV_10muMCa_0Que_hbe263,
    df_ts_50mV_10muMCa_0Que_hbe265,
    df_ts_50mV_10muMCa_0Que_hbe322,
    df_ts_50mV_10muMCa_0Que_hbe370,
    df_ts_50mV_10muMCa_0Que_hbe378,
    df_ts_50mV_10muMCa_10Que_hbe58,
    df_ts_50mV_10muMCa_10Que_hbe374,
    df_ts_50mV_10muMCa_10Que_hbe379,
    df_ts_50mV_10muMCa_10Que_hbe381,
    df_ts_50mV_10muMCa_10Que_hbe397,
    df_ts_50mV_10muMCa_100Que_hbe241,
    df_ts_50mV_10muMCa_100Que_hbe242,
    df_ts_50mV_10muMCa_100Que_hbe256,
    df_ts_50mV_10muMCa_100Que_hbe258,
    df_ts_50mV_10muMCa_100Que_hbe260,
    df_ts_50mV_10muMCa_100Que_hbe268,
    ])

# %%
df_10ca.dropna(inplace=True)

# %%
df_10ca.to_csv('./prepared_datasets/10_Ca_classification.csv',
                 index=False)

# %% [markdown]
# ## 100% Ca vs Quercetin

# %%
ts_50mV_100muMCa_0Que_hbe82 = Series(path_50mV_100muMCa_0Que + 'hbe82.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe89 = Series(path_50mV_100muMCa_0Que + 'hbe89.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe98 = Series(path_50mV_100muMCa_0Que + 'hbe98.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe105 = Series(path_50mV_100muMCa_0Que + 'hbe105.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe110 = Series(path_50mV_100muMCa_0Que + 'hbe110.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe111 = Series(path_50mV_100muMCa_0Que + 'hbe111.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe221 = Series(path_50mV_100muMCa_0Que + 'hbe221.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe223 = Series(path_50mV_100muMCa_0Que + 'hbe223.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe227 = Series(path_50mV_100muMCa_0Que + 'hbe227.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe272 = Series(path_50mV_100muMCa_0Que + 'hbe272.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe274 = Series(path_50mV_100muMCa_0Que + 'hbe274.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe276 = Series(path_50mV_100muMCa_0Que + 'hbe276.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe284 = Series(path_50mV_100muMCa_0Que + 'hbe284.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe303 = Series(path_50mV_100muMCa_0Que + 'hbe303.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe305 = Series(path_50mV_100muMCa_0Que + 'hbe305.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe307 = Series(path_50mV_100muMCa_0Que + 'hbe307.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe309 = Series(path_50mV_100muMCa_0Que + 'hbe309.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe311 = Series(path_50mV_100muMCa_0Que + 'hbe311.txt', '100Ca/0Que')

ts_50mV_100muMCa_10Que_hbe83 = Series(path_50mV_100muMCa_10Que + 'hbe83.txt', '100Ca/10Que')
ts_50mV_100muMCa_10Que_hbe85 = Series(path_50mV_100muMCa_10Que + 'hbe85.txt', '100Ca/10Que')
ts_50mV_100muMCa_10Que_hbe109 = Series(path_50mV_100muMCa_10Que + 'hbe109.txt', '100Ca/10Que')

ts_50mV_100muMCa_100Que_hbe277 = Series(path_50mV_100muMCa_100Que + 'hbe277.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe279 = Series(path_50mV_100muMCa_100Que + 'hbe279.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe281 = Series(path_50mV_100muMCa_100Que + 'hbe281.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe283 = Series(path_50mV_100muMCa_100Que + 'hbe283.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe290 = Series(path_50mV_100muMCa_100Que + 'hbe290.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe315 = Series(path_50mV_100muMCa_100Que + 'hbe315.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe317 = Series(path_50mV_100muMCa_100Que + 'hbe317.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe319 = Series(path_50mV_100muMCa_100Que + 'hbe319.txt', '100Ca/100Que')

# %%
df_ts_50mV_100muMCa_0Que_hbe82 = ts_50mV_100muMCa_0Que_hbe82.make_df()
df_ts_50mV_100muMCa_0Que_hbe89 = ts_50mV_100muMCa_0Que_hbe89.make_df()
df_ts_50mV_100muMCa_0Que_hbe98 = ts_50mV_100muMCa_0Que_hbe98.make_df()
df_ts_50mV_100muMCa_0Que_hbe105 = ts_50mV_100muMCa_0Que_hbe105.make_df()
df_ts_50mV_100muMCa_0Que_hbe110 = ts_50mV_100muMCa_0Que_hbe110.make_df()
df_ts_50mV_100muMCa_0Que_hbe111 = ts_50mV_100muMCa_0Que_hbe111.make_df()
df_ts_50mV_100muMCa_0Que_hbe221 = ts_50mV_100muMCa_0Que_hbe221.make_df()
df_ts_50mV_100muMCa_0Que_hbe223 = ts_50mV_100muMCa_0Que_hbe223.make_df()
df_ts_50mV_100muMCa_0Que_hbe227 = ts_50mV_100muMCa_0Que_hbe227.make_df()
df_ts_50mV_100muMCa_0Que_hbe272 = ts_50mV_100muMCa_0Que_hbe272.make_df()
df_ts_50mV_100muMCa_0Que_hbe274 = ts_50mV_100muMCa_0Que_hbe274.make_df()
df_ts_50mV_100muMCa_0Que_hbe276 = ts_50mV_100muMCa_0Que_hbe276.make_df()
df_ts_50mV_100muMCa_0Que_hbe284 = ts_50mV_100muMCa_0Que_hbe284.make_df()
df_ts_50mV_100muMCa_0Que_hbe303 = ts_50mV_100muMCa_0Que_hbe303.make_df()
df_ts_50mV_100muMCa_0Que_hbe305 = ts_50mV_100muMCa_0Que_hbe305.make_df()
df_ts_50mV_100muMCa_0Que_hbe307 = ts_50mV_100muMCa_0Que_hbe307.make_df()
df_ts_50mV_100muMCa_0Que_hbe309 = ts_50mV_100muMCa_0Que_hbe309.make_df()
df_ts_50mV_100muMCa_0Que_hbe311 = ts_50mV_100muMCa_0Que_hbe311.make_df()

df_ts_50mV_100muMCa_10Que_hbe83 = ts_50mV_100muMCa_10Que_hbe83.make_df()
df_ts_50mV_100muMCa_10Que_hbe85 = ts_50mV_100muMCa_10Que_hbe85.make_df()
df_ts_50mV_100muMCa_10Que_hbe109 = ts_50mV_100muMCa_10Que_hbe109.make_df()

df_ts_50mV_100muMCa_100Que_hbe277 = ts_50mV_100muMCa_100Que_hbe277.make_df()
df_ts_50mV_100muMCa_100Que_hbe279 = ts_50mV_100muMCa_100Que_hbe279.make_df()
df_ts_50mV_100muMCa_100Que_hbe281 = ts_50mV_100muMCa_100Que_hbe281.make_df()
df_ts_50mV_100muMCa_100Que_hbe283 = ts_50mV_100muMCa_100Que_hbe283.make_df()
df_ts_50mV_100muMCa_100Que_hbe290 = ts_50mV_100muMCa_100Que_hbe290.make_df()
df_ts_50mV_100muMCa_100Que_hbe315 = ts_50mV_100muMCa_100Que_hbe315.make_df()
df_ts_50mV_100muMCa_100Que_hbe317 = ts_50mV_100muMCa_100Que_hbe317.make_df()
df_ts_50mV_100muMCa_100Que_hbe319 = ts_50mV_100muMCa_100Que_hbe319.make_df()

# %%
df_100ca = pd.concat([
    df_ts_50mV_100muMCa_0Que_hbe82,
    df_ts_50mV_100muMCa_0Que_hbe89,
    df_ts_50mV_100muMCa_0Que_hbe98,
    df_ts_50mV_100muMCa_0Que_hbe105,
    df_ts_50mV_100muMCa_0Que_hbe110,
    df_ts_50mV_100muMCa_0Que_hbe111,
    df_ts_50mV_100muMCa_0Que_hbe221,
    df_ts_50mV_100muMCa_0Que_hbe223,
    df_ts_50mV_100muMCa_0Que_hbe227,
    df_ts_50mV_100muMCa_0Que_hbe272,
    df_ts_50mV_100muMCa_0Que_hbe274,
    df_ts_50mV_100muMCa_0Que_hbe276,
    df_ts_50mV_100muMCa_0Que_hbe284,
    df_ts_50mV_100muMCa_0Que_hbe303,
    df_ts_50mV_100muMCa_0Que_hbe305,
    df_ts_50mV_100muMCa_0Que_hbe307,
    df_ts_50mV_100muMCa_0Que_hbe309,
    df_ts_50mV_100muMCa_0Que_hbe311,
    df_ts_50mV_100muMCa_10Que_hbe83,
    df_ts_50mV_100muMCa_10Que_hbe85,
    df_ts_50mV_100muMCa_10Que_hbe109,
    df_ts_50mV_100muMCa_100Que_hbe277,
    df_ts_50mV_100muMCa_100Que_hbe279,
    df_ts_50mV_100muMCa_100Que_hbe281,
    df_ts_50mV_100muMCa_100Que_hbe283,
    df_ts_50mV_100muMCa_100Que_hbe290,
    df_ts_50mV_100muMCa_100Que_hbe315,
    df_ts_50mV_100muMCa_100Que_hbe317,
    df_ts_50mV_100muMCa_100Que_hbe319
    ])

# %%
df_100ca.dropna(inplace=True)

# %%
df_100ca.to_csv('./prepared_datasets/100_Ca_classification.csv',
                 index=False)

# %% [markdown]
# ### 0% Quercetin vs Ca

# %%
ts_50mV_0muMCa_0Que_hbe43_Ca = Series(path_50mV_0muMCa_0Que + 'hbe43.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe45_Ca = Series(path_50mV_0muMCa_0Que + 'hbe45.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe46_Ca = Series(path_50mV_0muMCa_0Que + 'hbe45.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe47_Ca = Series(path_50mV_0muMCa_0Que + 'hbe46.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe49_Ca = Series(path_50mV_0muMCa_0Que + 'hbe49.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe114_Ca = Series(path_50mV_0muMCa_0Que + 'hbe114.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe118_Ca = Series(path_50mV_0muMCa_0Que + 'hbe118.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe120_Ca = Series(path_50mV_0muMCa_0Que + 'hbe120.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe125_Ca = Series(path_50mV_0muMCa_0Que + 'hbe125.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe134_Ca = Series(path_50mV_0muMCa_0Que + 'hbe134.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe135_Ca = Series(path_50mV_0muMCa_0Que + 'hbe135.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe137_Ca = Series(path_50mV_0muMCa_0Que + 'hbe137.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe138_Ca = Series(path_50mV_0muMCa_0Que + 'hbe138.txt', '0Ca/0Que')
ts_50mV_0muMCa_0Que_hbe141_Ca = Series(path_50mV_0muMCa_0Que + 'hbe141.txt', '0Ca/0Que')

ts_50mV_10muMCa_0Que_hbe59_Ca = Series(path_50mV_10muMCa_0Que + 'hbe59.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe62_Ca = Series(path_50mV_10muMCa_0Que + 'hbe62.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe150_Ca = Series(path_50mV_10muMCa_0Que + 'hbe150.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe236_Ca = Series(path_50mV_10muMCa_0Que + 'hbe236.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe238_Ca = Series(path_50mV_10muMCa_0Que + 'hbe238.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe240_Ca = Series(path_50mV_10muMCa_0Que + 'hbe240.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe249_Ca = Series(path_50mV_10muMCa_0Que + 'hbe249.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe251_Ca = Series(path_50mV_10muMCa_0Que + 'hbe251.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe253_Ca = Series(path_50mV_10muMCa_0Que + 'hbe253.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe263_Ca = Series(path_50mV_10muMCa_0Que + 'hbe263.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe265_Ca = Series(path_50mV_10muMCa_0Que + 'hbe265.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe322_Ca = Series(path_50mV_10muMCa_0Que + 'hbe322.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe370_Ca = Series(path_50mV_10muMCa_0Que + 'hbe370.txt', '10Ca/0Que')
ts_50mV_10muMCa_0Que_hbe378_Ca = Series(path_50mV_10muMCa_0Que + 'hbe378.txt', '10Ca/0Que')

ts_50mV_100muMCa_0Que_hbe82_Ca = Series(path_50mV_100muMCa_0Que + 'hbe82.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe89_Ca = Series(path_50mV_100muMCa_0Que + 'hbe89.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe98_Ca = Series(path_50mV_100muMCa_0Que + 'hbe98.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe105_Ca = Series(path_50mV_100muMCa_0Que + 'hbe105.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe110_Ca = Series(path_50mV_100muMCa_0Que + 'hbe110.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe111_Ca = Series(path_50mV_100muMCa_0Que + 'hbe111.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe221_Ca = Series(path_50mV_100muMCa_0Que + 'hbe221.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe223_Ca = Series(path_50mV_100muMCa_0Que + 'hbe223.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe227_Ca = Series(path_50mV_100muMCa_0Que + 'hbe227.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe272_Ca = Series(path_50mV_100muMCa_0Que + 'hbe272.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe274_Ca = Series(path_50mV_100muMCa_0Que + 'hbe274.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe276_Ca = Series(path_50mV_100muMCa_0Que + 'hbe276.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe284_Ca = Series(path_50mV_100muMCa_0Que + 'hbe284.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe303_Ca = Series(path_50mV_100muMCa_0Que + 'hbe303.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe305_Ca = Series(path_50mV_100muMCa_0Que + 'hbe305.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe307_Ca = Series(path_50mV_100muMCa_0Que + 'hbe307.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe309_Ca = Series(path_50mV_100muMCa_0Que + 'hbe309.txt', '100Ca/0Que')
ts_50mV_100muMCa_0Que_hbe311_Ca = Series(path_50mV_100muMCa_0Que + 'hbe311.txt', '100Ca/0Que')

# %%
df_ts_50mV_0muMCa_0Que_hbe43_Ca = ts_50mV_0muMCa_0Que_hbe43_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe45_Ca = ts_50mV_0muMCa_0Que_hbe45_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe46_Ca = ts_50mV_0muMCa_0Que_hbe46_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe47_Ca = ts_50mV_0muMCa_0Que_hbe47_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe49_Ca = ts_50mV_0muMCa_0Que_hbe49_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe114_Ca = ts_50mV_0muMCa_0Que_hbe114_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe118_Ca = ts_50mV_0muMCa_0Que_hbe118_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe120_Ca = ts_50mV_0muMCa_0Que_hbe120_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe125_Ca = ts_50mV_0muMCa_0Que_hbe125_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe134_Ca = ts_50mV_0muMCa_0Que_hbe134_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe135_Ca = ts_50mV_0muMCa_0Que_hbe135_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe137_Ca = ts_50mV_0muMCa_0Que_hbe137_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe138_Ca = ts_50mV_0muMCa_0Que_hbe138_Ca.make_df()
df_ts_50mV_0muMCa_0Que_hbe141_Ca = ts_50mV_0muMCa_0Que_hbe141_Ca.make_df()

df_ts_50mV_10muMCa_0Que_hbe59_Ca = ts_50mV_10muMCa_0Que_hbe59_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe62_Ca = ts_50mV_10muMCa_0Que_hbe62_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe150_Ca = ts_50mV_10muMCa_0Que_hbe150_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe236_Ca = ts_50mV_10muMCa_0Que_hbe236_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe238_Ca = ts_50mV_10muMCa_0Que_hbe238_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe240_Ca = ts_50mV_10muMCa_0Que_hbe240_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe249_Ca = ts_50mV_10muMCa_0Que_hbe249_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe251_Ca = ts_50mV_10muMCa_0Que_hbe251_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe253_Ca = ts_50mV_10muMCa_0Que_hbe253_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe263_Ca = ts_50mV_10muMCa_0Que_hbe263_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe265_Ca = ts_50mV_10muMCa_0Que_hbe265_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe322_Ca = ts_50mV_10muMCa_0Que_hbe322_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe370_Ca = ts_50mV_10muMCa_0Que_hbe370_Ca.make_df()
df_ts_50mV_10muMCa_0Que_hbe378_Ca = ts_50mV_10muMCa_0Que_hbe378_Ca.make_df()

df_ts_50mV_100muMCa_0Que_hbe82_Ca = ts_50mV_100muMCa_0Que_hbe82_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe89_Ca = ts_50mV_100muMCa_0Que_hbe89_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe98_Ca = ts_50mV_100muMCa_0Que_hbe98_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe105_Ca = ts_50mV_100muMCa_0Que_hbe105_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe110_Ca = ts_50mV_100muMCa_0Que_hbe110_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe111_Ca = ts_50mV_100muMCa_0Que_hbe111_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe221_Ca = ts_50mV_100muMCa_0Que_hbe221_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe223_Ca = ts_50mV_100muMCa_0Que_hbe223_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe227_Ca = ts_50mV_100muMCa_0Que_hbe227_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe272_Ca = ts_50mV_100muMCa_0Que_hbe272_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe274_Ca = ts_50mV_100muMCa_0Que_hbe274_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe276_Ca = ts_50mV_100muMCa_0Que_hbe276_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe284_Ca = ts_50mV_100muMCa_0Que_hbe284_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe303_Ca = ts_50mV_100muMCa_0Que_hbe303_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe305_Ca = ts_50mV_100muMCa_0Que_hbe305_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe307_Ca = ts_50mV_100muMCa_0Que_hbe307_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe309_Ca = ts_50mV_100muMCa_0Que_hbe309_Ca.make_df()
df_ts_50mV_100muMCa_0Que_hbe311_Ca = ts_50mV_100muMCa_0Que_hbe311_Ca.make_df()

# %%
df_0que = pd.concat([
    df_ts_50mV_0muMCa_0Que_hbe43_Ca,
    df_ts_50mV_0muMCa_0Que_hbe45_Ca,
    df_ts_50mV_0muMCa_0Que_hbe46_Ca,
    df_ts_50mV_0muMCa_0Que_hbe47_Ca,
    df_ts_50mV_0muMCa_0Que_hbe49_Ca,
    df_ts_50mV_0muMCa_0Que_hbe114_Ca,
    df_ts_50mV_0muMCa_0Que_hbe118_Ca,
    df_ts_50mV_0muMCa_0Que_hbe120_Ca,
    df_ts_50mV_0muMCa_0Que_hbe125_Ca,
    df_ts_50mV_0muMCa_0Que_hbe134_Ca,
    df_ts_50mV_0muMCa_0Que_hbe135_Ca,
    df_ts_50mV_0muMCa_0Que_hbe137_Ca,
    df_ts_50mV_0muMCa_0Que_hbe138_Ca,
    df_ts_50mV_0muMCa_0Que_hbe141_Ca,
    df_ts_50mV_10muMCa_0Que_hbe59_Ca,
    df_ts_50mV_10muMCa_0Que_hbe62_Ca,
    df_ts_50mV_10muMCa_0Que_hbe150_Ca,
    df_ts_50mV_10muMCa_0Que_hbe236_Ca,
    df_ts_50mV_10muMCa_0Que_hbe238_Ca,
    df_ts_50mV_10muMCa_0Que_hbe240_Ca,
    df_ts_50mV_10muMCa_0Que_hbe249_Ca,
    df_ts_50mV_10muMCa_0Que_hbe251_Ca,
    df_ts_50mV_10muMCa_0Que_hbe253_Ca,
    df_ts_50mV_10muMCa_0Que_hbe263_Ca,
    df_ts_50mV_10muMCa_0Que_hbe265_Ca,
    df_ts_50mV_10muMCa_0Que_hbe322_Ca,
    df_ts_50mV_10muMCa_0Que_hbe370_Ca,
    df_ts_50mV_10muMCa_0Que_hbe378_Ca,
    df_ts_50mV_100muMCa_0Que_hbe82_Ca,
    df_ts_50mV_100muMCa_0Que_hbe89_Ca,
    df_ts_50mV_100muMCa_0Que_hbe98_Ca,
    df_ts_50mV_100muMCa_0Que_hbe105_Ca,
    df_ts_50mV_100muMCa_0Que_hbe110_Ca,
    df_ts_50mV_100muMCa_0Que_hbe111_Ca,
    df_ts_50mV_100muMCa_0Que_hbe221_Ca,
    df_ts_50mV_100muMCa_0Que_hbe223_Ca,
    df_ts_50mV_100muMCa_0Que_hbe227_Ca,
    df_ts_50mV_100muMCa_0Que_hbe272_Ca,
    df_ts_50mV_100muMCa_0Que_hbe274_Ca,
    df_ts_50mV_100muMCa_0Que_hbe276_Ca,
    df_ts_50mV_100muMCa_0Que_hbe284_Ca,
    df_ts_50mV_100muMCa_0Que_hbe303_Ca,
    df_ts_50mV_100muMCa_0Que_hbe305_Ca,
    df_ts_50mV_100muMCa_0Que_hbe307_Ca,
    df_ts_50mV_100muMCa_0Que_hbe309_Ca,
    df_ts_50mV_100muMCa_0Que_hbe311_Ca,
])

# %%
df_0que.dropna(inplace=True)

# %%
df_0que_concentration.to_csv('./prepared_datasets/0_Que_classification.csv',
                 index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7q/rf64ybp94z73qjhb3gl5lg1m0000gn/T/ipykernel_68858/2726008665.py in <module>
# ----> 1 df_0que_concentration.to_csv('./prepared_datasets/0_Que_classification.csv',
#       2                  index=False)
#
# NameError: name 'df_0que_concentration' is not defined

# %% [markdown]
# ### 10% Quercetin vs Ca

# %%
ts_50mV_0muMCa_10Que_hbe50_Ca = Series(path_50mV_0muMCa_10Que + 'hbe50.txt', '0Ca/10Que')
ts_50mV_0muMCa_10Que_hbe51_Ca = Series(path_50mV_0muMCa_10Que + 'hbe51.txt', '0Ca/10Que')
ts_50mV_0muMCa_10Que_hbe52_Ca = Series(path_50mV_0muMCa_10Que + 'hbe52.txt', '0Ca/10Que')
ts_50mV_0muMCa_10Que_hbe54_Ca = Series(path_50mV_0muMCa_10Que + 'hbe54.txt', '0Ca/10Que')
ts_50mV_0muMCa_10Que_hbe56_Ca = Series(path_50mV_0muMCa_10Que + 'hbe56.txt', '0Ca/10Que')

ts_50mV_10muMCa_10Que_hbe58_Ca = Series(path_50mV_10muMCa_10Que + 'hbe58.txt', '10Ca/10Que')
ts_50mV_10muMCa_10Que_hbe374_Ca = Series(path_50mV_10muMCa_10Que + 'hbe374.txt', '10Ca/10Que')
ts_50mV_10muMCa_10Que_hbe379_Ca = Series(path_50mV_10muMCa_10Que + 'hbe379.txt', '10Ca/10Que')
ts_50mV_10muMCa_10Que_hbe381_Ca = Series(path_50mV_10muMCa_10Que + 'hbe381.txt', '10Ca/10Que')
ts_50mV_10muMCa_10Que_hbe397_Ca = Series(path_50mV_10muMCa_10Que + 'hbe397.txt', '10Ca/10Que')

ts_50mV_100muMCa_10Que_hbe83_Ca = Series(path_50mV_100muMCa_10Que + 'hbe83.txt', '100Ca/10Que')
ts_50mV_100muMCa_10Que_hbe85_Ca = Series(path_50mV_100muMCa_10Que + 'hbe85.txt', '100Ca/10Que')
ts_50mV_100muMCa_10Que_hbe109_Ca = Series(path_50mV_100muMCa_10Que + 'hbe109.txt', '100Ca/10Que')

# %%
df_ts_50mV_0muMCa_10Que_hbe50_Ca = ts_50mV_0muMCa_10Que_hbe50_Ca.make_df()
df_ts_50mV_0muMCa_10Que_hbe51_Ca = ts_50mV_0muMCa_10Que_hbe51_Ca.make_df()
df_ts_50mV_0muMCa_10Que_hbe52_Ca = ts_50mV_0muMCa_10Que_hbe52_Ca.make_df()
df_ts_50mV_0muMCa_10Que_hbe54_Ca = ts_50mV_0muMCa_10Que_hbe54_Ca.make_df()
df_ts_50mV_0muMCa_10Que_hbe56_Ca = ts_50mV_0muMCa_10Que_hbe56_Ca.make_df()

df_ts_50mV_10muMCa_10Que_hbe58_Ca = ts_50mV_10muMCa_10Que_hbe58_Ca.make_df()
df_ts_50mV_10muMCa_10Que_hbe374_Ca = ts_50mV_10muMCa_10Que_hbe374_Ca.make_df()
df_ts_50mV_10muMCa_10Que_hbe379_Ca = ts_50mV_10muMCa_10Que_hbe379_Ca.make_df()
df_ts_50mV_10muMCa_10Que_hbe381_Ca = ts_50mV_10muMCa_10Que_hbe381_Ca.make_df()
df_ts_50mV_10muMCa_10Que_hbe397_Ca = ts_50mV_10muMCa_10Que_hbe397_Ca.make_df()

df_ts_50mV_100muMCa_10Que_hbe83_Ca = ts_50mV_100muMCa_10Que_hbe83_Ca.make_df()
df_ts_50mV_100muMCa_10Que_hbe85_Ca = ts_50mV_100muMCa_10Que_hbe85_Ca.make_df()
df_ts_50mV_100muMCa_10Que_hbe109_Ca = ts_50mV_100muMCa_10Que_hbe109_Ca.make_df()

# %%
df_10que = pd.concat([
    df_ts_50mV_0muMCa_10Que_hbe50_Ca,
    df_ts_50mV_0muMCa_10Que_hbe51_Ca,
    df_ts_50mV_0muMCa_10Que_hbe52_Ca,
    df_ts_50mV_0muMCa_10Que_hbe54_Ca,
    df_ts_50mV_0muMCa_10Que_hbe56_Ca,
    df_ts_50mV_10muMCa_10Que_hbe58_Ca,
    df_ts_50mV_10muMCa_10Que_hbe374_Ca,
    df_ts_50mV_10muMCa_10Que_hbe379_Ca,
    df_ts_50mV_10muMCa_10Que_hbe381_Ca,
    df_ts_50mV_10muMCa_10Que_hbe397_Ca,
    df_ts_50mV_100muMCa_10Que_hbe83_Ca,
    df_ts_50mV_100muMCa_10Que_hbe85_Ca,
    df_ts_50mV_100muMCa_10Que_hbe109_Ca
])

# %%
df_10que.dropna(inplace=True)

# %%
df_10que.to_csv('./prepared_datasets/10_Que_classification.csv',
                 index=False)

# %% [markdown]
# ### 100% Quercetin vs Ca

# %%
ts_50mV_0muMCa_100Que_hbe115_Ca = Series(path_50mV_0muMCa_100Que + 'hbe115.txt', '0Ca/100Que')
ts_50mV_0muMCa_100Que_hbe117_Ca = Series(path_50mV_0muMCa_100Que + 'hbe117.txt', '0Ca/100Que')
ts_50mV_0muMCa_100Que_hbe123_Ca = Series(path_50mV_0muMCa_100Que + 'hbe123.txt', '0Ca/100Que')

ts_50mV_10muMCa_100Que_hbe241_Ca = Series(path_50mV_10muMCa_100Que + 'hbe241.txt', '10Ca/100Que')
ts_50mV_10muMCa_100Que_hbe242_Ca = Series(path_50mV_10muMCa_100Que + 'hbe242.txt', '10Ca/100Que')
ts_50mV_10muMCa_100Que_hbe256_Ca = Series(path_50mV_10muMCa_100Que + 'hbe256.txt', '10Ca/100Que')
ts_50mV_10muMCa_100Que_hbe258_Ca = Series(path_50mV_10muMCa_100Que + 'hbe258.txt', '10Ca/100Que')
ts_50mV_10muMCa_100Que_hbe260_Ca = Series(path_50mV_10muMCa_100Que + 'hbe260.txt', '10Ca/100Que')
ts_50mV_10muMCa_100Que_hbe268_Ca = Series(path_50mV_10muMCa_100Que + 'hbe268.txt', '10Ca/100Que')

ts_50mV_100muMCa_100Que_hbe277_Ca = Series(path_50mV_100muMCa_100Que + 'hbe277.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe279_Ca = Series(path_50mV_100muMCa_100Que + 'hbe279.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe281_Ca = Series(path_50mV_100muMCa_100Que + 'hbe281.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe283_Ca = Series(path_50mV_100muMCa_100Que + 'hbe283.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe290_Ca = Series(path_50mV_100muMCa_100Que + 'hbe290.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe315_Ca = Series(path_50mV_100muMCa_100Que + 'hbe315.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe317_Ca = Series(path_50mV_100muMCa_100Que + 'hbe317.txt', '100Ca/100Que')
ts_50mV_100muMCa_100Que_hbe319_Ca = Series(path_50mV_100muMCa_100Que + 'hbe319.txt', '100Ca/100Que')

# %%
df_ts_50mV_0muMCa_100Que_hbe115_Ca = ts_50mV_0muMCa_100Que_hbe115_Ca.make_df()
df_ts_50mV_0muMCa_100Que_hbe117_Ca = ts_50mV_0muMCa_100Que_hbe117_Ca.make_df()
df_ts_50mV_0muMCa_100Que_hbe123_Ca = ts_50mV_0muMCa_100Que_hbe123_Ca.make_df()

df_ts_50mV_10muMCa_100Que_hbe241_Ca = ts_50mV_10muMCa_100Que_hbe241_Ca.make_df()
df_ts_50mV_10muMCa_100Que_hbe242_Ca = ts_50mV_10muMCa_100Que_hbe242_Ca.make_df()
df_ts_50mV_10muMCa_100Que_hbe256_Ca = ts_50mV_10muMCa_100Que_hbe256_Ca.make_df()
df_ts_50mV_10muMCa_100Que_hbe258_Ca = ts_50mV_10muMCa_100Que_hbe258_Ca.make_df()
df_ts_50mV_10muMCa_100Que_hbe260_Ca = ts_50mV_10muMCa_100Que_hbe260_Ca.make_df()
df_ts_50mV_10muMCa_100Que_hbe268_Ca = ts_50mV_10muMCa_100Que_hbe268_Ca.make_df()

df_ts_50mV_100muMCa_100Que_hbe277_Ca = ts_50mV_100muMCa_100Que_hbe277_Ca.make_df()
df_ts_50mV_100muMCa_100Que_hbe279_Ca = ts_50mV_100muMCa_100Que_hbe279_Ca.make_df()
df_ts_50mV_100muMCa_100Que_hbe281_Ca = ts_50mV_100muMCa_100Que_hbe281_Ca.make_df()
df_ts_50mV_100muMCa_100Que_hbe283_Ca = ts_50mV_100muMCa_100Que_hbe283_Ca.make_df()
df_ts_50mV_100muMCa_100Que_hbe290_Ca = ts_50mV_100muMCa_100Que_hbe290_Ca.make_df()
df_ts_50mV_100muMCa_100Que_hbe315_Ca = ts_50mV_100muMCa_100Que_hbe315_Ca.make_df()
df_ts_50mV_100muMCa_100Que_hbe317_Ca = ts_50mV_100muMCa_100Que_hbe317_Ca.make_df()
df_ts_50mV_100muMCa_100Que_hbe319_Ca = ts_50mV_100muMCa_100Que_hbe319_Ca.make_df()

# %%
df_100que = pd.concat([
    df_ts_50mV_0muMCa_100Que_hbe115_Ca,
    df_ts_50mV_0muMCa_100Que_hbe117_Ca,
    df_ts_50mV_0muMCa_100Que_hbe123_Ca,
    df_ts_50mV_10muMCa_100Que_hbe241_Ca,
    df_ts_50mV_10muMCa_100Que_hbe242_Ca,
    df_ts_50mV_10muMCa_100Que_hbe256_Ca,
    df_ts_50mV_10muMCa_100Que_hbe258_Ca,
    df_ts_50mV_10muMCa_100Que_hbe260_Ca,
    df_ts_50mV_10muMCa_100Que_hbe268_Ca,
    df_ts_50mV_100muMCa_100Que_hbe277_Ca,
    df_ts_50mV_100muMCa_100Que_hbe279_Ca, 
    df_ts_50mV_100muMCa_100Que_hbe281_Ca, 
    df_ts_50mV_100muMCa_100Que_hbe283_Ca, 
    df_ts_50mV_100muMCa_100Que_hbe290_Ca, 
    df_ts_50mV_100muMCa_100Que_hbe315_Ca,
    df_ts_50mV_100muMCa_100Que_hbe317_Ca,
    df_ts_50mV_100muMCa_100Que_hbe319_Ca,
])

# %%
df_100que.dropna(inplace=True)

# %%
df_100que.to_csv('./prepared_datasets/100_Que_classification.csv',
                 index=False)
